# %%
#Given input list
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#initializing count variable
count=0
#checking the message ERROR in the given list if found incrementing count value and printing Total Error Count
for i in logs:
   if i=="ERROR":
    count=count+1
print("Total ERROR Count:",count)
# Out:
# Total ERROR Count: 2
